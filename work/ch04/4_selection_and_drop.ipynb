# %%
from pandas import Series, DataFrame
import numpy as np
import pandas as pd

# %%
df["account"].head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_464/1886113817.py in <module>
# ----> 1 df["account"].head(3)
#
# NameError: name 'df' is not defined

# %%
# !conda install --y xlrd
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/linux-64::spyder==5.1.5=py39h06a4308_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/linux-64::conda-build==3.21.5=py39h06a4308_0
#   - defaults/linux-64::watchdog==2.1.3=py39h06a4308_0
#   - defaults/linux-64::scikit-image==0.18.3=py39h51133e4_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/linux-64::anaconda==2021.11=py39_0
#   - defaults/linux-64::anaconda-navigator==2.1.1=py39_0
#   - defaults/linux-64::anaconda-client==1.9.0=py39h06a4308_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/linux-64::astropy==4.3.1=py39h09021b7_0
#   - defaults/linux-64::bokeh==2.4.1=py39h06a4308_0
#   - defaults/linux-64::distributed==2021.10.0=py39h06a4308_0
# ...

# %%
df = pd.read_excel("./data/excel-comp-data.xlsx")
df.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df["account"].head(3) # 한개(account) column을 선택.
# Out:
# 0    211829
# 1    320563
# 2    648336
# Name: account, dtype: int64

# %%
df[["account", "street", "state"]].head(3) #세 개(account, street, state)의 column을 선택.
# Out:
#    account                                street          state
# 0   211829                    34456 Sean Highway          Texas
# 1   320563                     1311 Alvis Tunnel  NorthCarolina
# 2   648336  62184 Schamberger Underpass Apt. 231           Iowa

# %%
df[:3] # column 이름 없이 사용하는 index number는 row기준 표시
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
df["account"][:3]
# Out:
# 0    211829
# 1    320563
# 2    648336
# Name: account, dtype: int64

# %%
account_series = df["account"]
account_series[:3]
# Out:
# 0    211829
# 1    320563
# 2    648336
# Name: account, dtype: int64

# %%
account_series[[0,1,2]]
# Out:
# 0    211829
# 1    320563
# 2    648336
# Name: account, dtype: int64

# %%
account_series[account_series<250000]
# Out:
# 0     211829
# 3     109996
# 4     121213
# 5     132971
# 6     145068
# 7     205217
# 8     209744
# 9     212303
# 10    214098
# 11    231907
# 12    242368
# Name: account, dtype: int64

# %%
df.index = df["account"]
del df["account"]
df.head()
# Out:
#                                 name                                street  \
# account
# 211829    Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 320563                Walter-Trantow                     1311 Alvis Tunnel
# 648336    Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 109996   D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 121213                 Bauch-Goldner                   7274 Marissa Common
#
#                     city          state  postal-code     Jan     Feb    Mar
# account
# 211829        New Jaycob          Texas        28752   10000   62000  35000
# 320563     Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 648336    New Lilianland           Iowa        76517   91000  120000  35000
# 109996        Hyattburgh          Maine        46021   45000  120000  10000
# 121213   Shanahanchester     California        49681  162000  120000  35000

# %%
df[["name","street"]][:2] # Column과 index number
# Out:
#                                name              street
# account
# 211829   Kerluke, Koepp and Hilpert  34456 Sean Highway
# 320563               Walter-Trantow   1311 Alvis Tunnel

# %%
df.loc[[211829,320563],["name","street"]] # Column과  index name
# Out:
#                                name              street
# account
# 211829   Kerluke, Koepp and Hilpert  34456 Sean Highway
# 320563               Walter-Trantow   1311 Alvis Tunnel

# %%
df.iloc[:2,:2] # Column number와 index number
# Out:
#                                name              street
# account
# 211829   Kerluke, Koepp and Hilpert  34456 Sean Highway
# 320563               Walter-Trantow   1311 Alvis Tunnel

# %%
df.index = list(range(0,15))
df.head()
# Out:
#                           name                                street  \
# 0   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1               Walter-Trantow                     1311 Alvis Tunnel
# 2   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df.drop(1) #index number으로 drop
# Out:
#                                 name                                street  \
# 0         Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 2         Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3        D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4                      Bauch-Goldner                   7274 Marissa Common
# 5   Williamson, Schumm and Hettinger                  89403 Casimer Spring
# 6                         Casper LLC          340 Consuela Bridge Apt. 400
# 7                   Kovacek-Johnston          91971 Cronin Vista Suite 601
# 8                     Champlin-Morar                      26739 Grant Lock
# 9                     Gerhold-Maggio             366 Maggio Grove Apt. 998
# 10       Goodwin, Homenick and Jerde             649 Cierra Forks Apt. 078
# 11                        Hahn-Moore              18115 Olivine Throughway
# ...

# %%
df.drop([0,1,2,3,]) #개 이상의 index number로 drop
# Out:
#                                 name                        street  \
# 4                      Bauch-Goldner           7274 Marissa Common
# 5   Williamson, Schumm and Hettinger          89403 Casimer Spring
# 6                         Casper LLC  340 Consuela Bridge Apt. 400
# 7                   Kovacek-Johnston  91971 Cronin Vista Suite 601
# 8                     Champlin-Morar              26739 Grant Lock
# 9                     Gerhold-Maggio     366 Maggio Grove Apt. 998
# 10       Goodwin, Homenick and Jerde     649 Cierra Forks Apt. 078
# 11                        Hahn-Moore      18115 Olivine Throughway
# 12      Frami, Anderson and Donnelly               182 Bertie Road
# 13                       Walsh-Haley          2624 Beatty Parkways
# 14                     McDermott PLC         8917 Bergstrom Meadow
#
#                  city         state  postal-code     Jan     Feb     Mar
# 4     Shanahanchester    California        49681  162000  120000   35000
# ...

# %%
df.drop("city", axis=1) #axis 지정으로 축을 기준으로 drop -> column 중에 "city" (axis = 1이면 column에서 city를 찾는건가?)
# Out:
#                                 name                                street  \
# 0         Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1                     Walter-Trantow                     1311 Alvis Tunnel
# 2         Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3        D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4                      Bauch-Goldner                   7274 Marissa Common
# 5   Williamson, Schumm and Hettinger                  89403 Casimer Spring
# 6                         Casper LLC          340 Consuela Bridge Apt. 400
# 7                   Kovacek-Johnston          91971 Cronin Vista Suite 601
# 8                     Champlin-Morar                      26739 Grant Lock
# 9                     Gerhold-Maggio             366 Maggio Grove Apt. 998
# 10       Goodwin, Homenick and Jerde             649 Cierra Forks Apt. 078
# ...
